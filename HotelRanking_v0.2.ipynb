# %% [markdown]
# # Customer Alliance Hotel Ranking Project

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing Data

# %%
# importing data while parsing 'crawled_at' column as datetime object

data_df = pd.read_csv('TA_CityRank_Hack_DD_pull_3.csv', sep=';', low_memory=False, skipinitialspace=True, error_bad_lines=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
     print(data_df.head(10))
# Out:
#    hotel_id              hotel_name            street zip_code    city  \
# 0        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 1        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 2        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 3        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 4        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 5        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 6        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 7        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 8        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
# 9        50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  Berlin
#
#   country  crawled_at  review_count_state  average_rating_state  \
# 0      DE  2015-08-19                 270                  80.0
# 1      DE  2015-08-20                 270                  80.0
# 2      DE  2015-08-21                 270                  80.0
# 3      DE  2015-08-22                 270                  80.0
# 4      DE  2015-08-23                 270                  80.0
# 5      DE  2015-08-24                 270                  80.0
# 6      DE  2015-08-25                 270                  80.0
# 7      DE  2015-08-26                 270                  80.0
# 8      DE  2015-08-27                 270                  80.0
# 9      DE  2015-08-28                 270                  80.0
#
#    sleep_rating_state  location_rating_state  room_rating_state  \
# 0                80.0                   90.0               80.0
# 1                80.0                   90.0               80.0
# 2                80.0                   90.0               80.0
# 3                80.0                   90.0               80.0
# 4                80.0                   90.0               80.0
# 5                80.0                   90.0               80.0
# 6                80.0                   90.0               80.0
# 7                80.0                   90.0               80.0
# 8                80.0                   90.0               80.0
# 9                80.0                   90.0               80.0
#
#    service_rating_state  value_rating_state  clean_rating_state  city_rank  \
# 0                  90.0                80.0                90.0      144.0
# 1                  90.0                80.0                90.0      144.0
# 2                  90.0                80.0                90.0      145.0
# 3                  90.0                80.0                90.0      146.0
# 4                  90.0                80.0                90.0      146.0
# 5                  90.0                80.0                90.0      145.0
# 6                  90.0                80.0                90.0      146.0
# 7                  90.0                80.0                90.0      146.0
# 8                  90.0                80.0                90.0      147.0
# 9                  90.0                80.0                90.0      147.0
#
#    cities  hotel_rank  response_rate_negative_count_todate  \
# 0   668.0         NaN                                  NaN
# 1   668.0         NaN                                  NaN
# 2   668.0         NaN                                  NaN
# 3   668.0         NaN                                  NaN
# 4   668.0         NaN                                  NaN
# 5   668.0         NaN                                  NaN
# 6   668.0         NaN                                  NaN
# 7   668.0         NaN                                  NaN
# 8   668.0         NaN                                  NaN
# 9   668.0         NaN                                  NaN
#
#    response_rate_neutral_count_todate  response_rate_positive_count_todate  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
#
#    response_rate_count_todate  response_rate_negative_todate  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
# 5                         NaN                            NaN
# 6                         NaN                            NaN
# 7                         NaN                            NaN
# 8                         NaN                            NaN
# 9                         NaN                            NaN
#
#    response_rate_neutral_todate  response_rate_positive_todate  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# 5                           NaN                            NaN
# 6                           NaN                            NaN
# 7                           NaN                            NaN
# 8                           NaN                            NaN
# 9                           NaN                            NaN
#
#    response_rate_todate  average_rating_positive_count_todate  \
# 0                   NaN                                   NaN
# 1                   NaN                                   NaN
# 2                   NaN                                   NaN
# 3                   NaN                                   NaN
# 4                   NaN                                   NaN
# 5                   NaN                                   NaN
# 6                   NaN                                   NaN
# 7                   NaN                                   NaN
# 8                   NaN                                   NaN
# 9                   NaN                                   NaN
#
#    average_rating_neutral_count_todate  average_rating_negative_count_todate  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
# 5                                  NaN                                   NaN
# 6                                  NaN                                   NaN
# 7                                  NaN                                   NaN
# 8                                  NaN                                   NaN
# 9                                  NaN                                   NaN
#
#    average_rating_count_todate  average_rating_normalized_todate  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# 5                          NaN                               NaN
# 6                          NaN                               NaN
# 7                          NaN                               NaN
# 8                          NaN                               NaN
# 9                          NaN                               NaN
#
#    sleep_rating_positive_count_todate  sleep_rating_neutral_count_todate  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# 5                                 NaN                                NaN
# 6                                 NaN                                NaN
# 7                                 NaN                                NaN
# 8                                 NaN                                NaN
# 9                                 NaN                                NaN
#
#    sleep_rating_negative_count_todate  sleep_rating_count_todate  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# 5                                 NaN                        NaN
# 6                                 NaN                        NaN
# 7                                 NaN                        NaN
# 8                                 NaN                        NaN
# 9                                 NaN                        NaN
#
#    sleep_rating_normalized_todate  location_rating_positive_count_todate  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
# 5                             NaN                                    NaN
# 6                             NaN                                    NaN
# 7                             NaN                                    NaN
# 8                             NaN                                    NaN
# 9                             NaN                                    NaN
#
#    location_rating_neutral_count_todate  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
#    location_rating_negative_count_todate  location_rating_count_todate  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# 5                                    NaN                           NaN
# 6                                    NaN                           NaN
# 7                                    NaN                           NaN
# 8                                    NaN                           NaN
# 9                                    NaN                           NaN
#
#    location_rating_normalized_todate  room_rating_positive_count_todate  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# 5                                NaN                                NaN
# 6                                NaN                                NaN
# 7                                NaN                                NaN
# 8                                NaN                                NaN
# 9                                NaN                                NaN
#
#    room_rating_neutral_count_todate  room_rating_negative_count_todate  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# 5                               NaN                                NaN
# 6                               NaN                                NaN
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
#
#    room_rating_count_todate  room_rating_normalized_todate  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
# 5                       NaN                            NaN
# 6                       NaN                            NaN
# 7                       NaN                            NaN
# 8                       NaN                            NaN
# 9                       NaN                            NaN
#
#    service_rating_positive_count_todate  service_rating_neutral_count_todate  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# 5                                   NaN                                  NaN
# 6                                   NaN                                  NaN
# 7                                   NaN                                  NaN
# 8                                   NaN                                  NaN
# 9                                   NaN                                  NaN
#
#    service_rating_negative_count_todate  service_rating_count_todate  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# 6                                   NaN                          NaN
# 7                                   NaN                          NaN
# 8                                   NaN                          NaN
# 9                                   NaN                          NaN
#
#    service_rating_normalized_todate  value_rating_positive_count_todate  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
# 5                               NaN                                 NaN
# 6                               NaN                                 NaN
# 7                               NaN                                 NaN
# 8                               NaN                                 NaN
# 9                               NaN                                 NaN
#
#    value_rating_neutral_count_todate  value_rating_negative_count_todate  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
# 6                                NaN                                 NaN
# 7                                NaN                                 NaN
# 8                                NaN                                 NaN
# 9                                NaN                                 NaN
#
#    value_rating_count_todate  value_rating_normalized_todate  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
# 5                        NaN                             NaN
# 6                        NaN                             NaN
# 7                        NaN                             NaN
# 8                        NaN                             NaN
# 9                        NaN                             NaN
#
#    clean_rating_positive_count_todate  clean_rating_neutral_count_todate  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# 5                                 NaN                                NaN
# 6                                 NaN                                NaN
# 7                                 NaN                                NaN
# 8                                 NaN                                NaN
# 9                                 NaN                                NaN
#
#    clean_rating_negative_count_todate  clean_rating_count_todate  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# 5                                 NaN                        NaN
# 6                                 NaN                        NaN
# 7                                 NaN                        NaN
# 8                                 NaN                        NaN
# 9                                 NaN                        NaN
#
#    clean_rating_normalized_todate
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776337 entries, 0 to 776336
# Data columns (total 61 columns):
# hotel_id                                 776337 non-null int64
# hotel_name                               776337 non-null object
# street                                   776305 non-null object
# zip_code                                 776337 non-null object
# city                                     776337 non-null object
# country                                  776337 non-null object
# crawled_at                               776337 non-null object
# review_count_state                       776337 non-null int64
# average_rating_state                     776337 non-null float64
# sleep_rating_state                       133359 non-null float64
# location_rating_state                    133376 non-null float64
# room_rating_state                        133202 non-null float64
# service_rating_state                     133376 non-null float64
# value_rating_state                       133145 non-null float64
# clean_rating_state                       133234 non-null float64
# city_rank                                734966 non-null float64
# cities                                   734966 non-null float64
# hotel_rank                               0 non-null float64
# response_rate_negative_count_todate      173180 non-null float64
# response_rate_neutral_count_todate       173180 non-null float64
# response_rate_positive_count_todate      173180 non-null float64
# response_rate_count_todate               173180 non-null float64
# response_rate_negative_todate            173180 non-null float64
# response_rate_neutral_todate             173180 non-null float64
# response_rate_positive_todate            173180 non-null float64
# response_rate_todate                     173180 non-null float64
# average_rating_positive_count_todate     173180 non-null float64
# average_rating_neutral_count_todate      173180 non-null float64
# average_rating_negative_count_todate     173180 non-null float64
# average_rating_count_todate              173180 non-null float64
# average_rating_normalized_todate         173180 non-null float64
# sleep_rating_positive_count_todate       173180 non-null float64
# sleep_rating_neutral_count_todate        173180 non-null float64
# sleep_rating_negative_count_todate       173180 non-null float64
# sleep_rating_count_todate                173180 non-null float64
# sleep_rating_normalized_todate           173180 non-null float64
# location_rating_positive_count_todate    173180 non-null float64
# location_rating_neutral_count_todate     173180 non-null float64
# location_rating_negative_count_todate    173180 non-null float64
# location_rating_count_todate             173180 non-null float64
# location_rating_normalized_todate        173180 non-null float64
# room_rating_positive_count_todate        173180 non-null float64
# room_rating_neutral_count_todate         173180 non-null float64
# room_rating_negative_count_todate        173180 non-null float64
# room_rating_count_todate                 173180 non-null float64
# room_rating_normalized_todate            173180 non-null float64
# service_rating_positive_count_todate     173180 non-null float64
# service_rating_neutral_count_todate      173180 non-null float64
# service_rating_negative_count_todate     173180 non-null float64
# service_rating_count_todate              173180 non-null float64
# service_rating_normalized_todate         173180 non-null float64
# value_rating_positive_count_todate       173180 non-null float64
# value_rating_neutral_count_todate        173180 non-null float64
# value_rating_negative_count_todate       173180 non-null float64
# value_rating_count_todate                173180 non-null float64
# value_rating_normalized_todate           173180 non-null float64
# clean_rating_positive_count_todate       173180 non-null float64
# clean_rating_neutral_count_todate        173180 non-null float64
# clean_rating_negative_count_todate       173180 non-null float64
# clean_rating_count_todate                173180 non-null float64
# clean_rating_normalized_todate           173180 non-null float64
# dtypes: float64(53), int64(2), object(6)
# memory usage: 361.3+ MB

# %%
data_df.describe()
# Out:
#             hotel_id  review_count_state  average_rating_state  \
# count  776337.000000       776337.000000         776337.000000
# mean    90389.099417          562.764177             80.782250
# std     86677.161277          848.583046              9.340559
# min        19.000000            1.000000             20.000000
# 25%     25145.000000          148.000000             80.000000
# 50%     42661.000000          334.000000             80.000000
# 75%    137741.000000          692.000000             90.000000
# max    352001.000000        34587.000000            100.000000
#
#        sleep_rating_state  location_rating_state  room_rating_state  \
# count       133359.000000          133376.000000      133202.000000
# mean            82.152311              87.564854          78.360385
# std              8.525900               9.669628          10.269200
# min             20.000000              50.000000          20.000000
# 25%             80.000000              80.000000          70.000000
# 50%             80.000000              90.000000          80.000000
# 75%             90.000000              90.000000          90.000000
# max            100.000000             100.000000         100.000000
#
#        service_rating_state  value_rating_state  clean_rating_state  \
# count         133376.000000       133145.000000       133234.000000
# mean              82.226562           80.602276           85.899995
# std                8.958460            8.169351            9.047269
# min               40.000000           40.000000           40.000000
# 25%               80.000000           80.000000           80.000000
# 50%               80.000000           80.000000           90.000000
# 75%               90.000000           90.000000           90.000000
# max              100.000000          100.000000          100.000000
#
#            city_rank               ...                \
# count  734966.000000               ...
# mean      461.595210               ...
# std       667.303172               ...
# min         1.000000               ...
# 25%       111.000000               ...
# 50%       274.000000               ...
# 75%       587.000000               ...
# max     13232.000000               ...
#
#        value_rating_positive_count_todate  value_rating_neutral_count_todate  \
# count                       173180.000000                      173180.000000
# mean                             0.320176                           0.068564
# std                              0.670150                           0.279408
# min                              0.000000                           0.000000
# 25%                              0.000000                           0.000000
# 50%                              0.000000                           0.000000
# 75%                              1.000000                           0.000000
# max                             15.000000                           6.000000
#
#        value_rating_negative_count_todate  value_rating_count_todate  \
# count                       173180.000000              173180.000000
# mean                             0.010359                   0.399099
# std                              0.106369                   0.771805
# min                              0.000000                   0.000000
# 25%                              0.000000                   0.000000
# 50%                              0.000000                   0.000000
# 75%                              0.000000                   1.000000
# max                              5.000000                  21.000000
#
#        value_rating_normalized_todate  clean_rating_positive_count_todate  \
# count                   173180.000000                       173180.000000
# mean                        25.088783                            0.341466
# std                         39.492981                            0.709165
# min                          0.000000                            0.000000
# 25%                          0.000000                            0.000000
# 50%                          0.000000                            0.000000
# 75%                         60.000000                            1.000000
# max                        100.000000                           15.000000
#
#        clean_rating_neutral_count_todate  clean_rating_negative_count_todate  \
# count                      173180.000000                       173180.000000
# mean                            0.038457                            0.006161
# std                             0.208658                            0.079931
# min                             0.000000                            0.000000
# 25%                             0.000000                            0.000000
# 50%                             0.000000                            0.000000
# 75%                             0.000000                            0.000000
# max                             5.000000                            2.000000
#
#        clean_rating_count_todate  clean_rating_normalized_todate
# count              173180.000000                   173180.000000
# mean                    0.386084                       25.760947
# std                     0.765275                       41.214509
# min                     0.000000                        0.000000
# 25%                     0.000000                        0.000000
# 50%                     0.000000                        0.000000
# 75%                     1.000000                       80.000000
# max                    17.000000                      100.000000
#
# [8 rows x 55 columns]

# %% [markdown]
# ### Data Integrity Check and EDA

# %%
# How many hotels before dropping rows where city_rank (response) is NA? 1478 hotels. There are 16 more unique hotel_ids than
# there are hotel names

data_df['hotel_id']=data_df['hotel_id'].astype(str)
print(data_df[['hotel_id','hotel_name']].nunique())
# Out:
# hotel_id      1478
# hotel_name    1462
# dtype: int64

# %%
# How many hotels after dropping rows where city_rank (response) is NA? 1456, so we lose 22 hotels which have no useful data. 
# Again there are fewer hotel names as there are ids

print(data_df[data_df['city_rank'].notna()].shape)
print(data_df[data_df['city_rank'].notna()][['hotel_id','hotel_name']].nunique())
# Out:
# (734966, 61)
# hotel_id      1456
# hotel_name    1440
# dtype: int64

# %%
# storing the rows of the nan city_rank out of main dataframe. 41,371 rows linked to 978 hotels

data_missing_df=data_df[data_df['city_rank'].isna()]
print(data_missing_df.shape)
print(data_missing_df[['hotel_id','hotel_name']].nunique())
# Out:
# (41371, 61)
# hotel_id      978
# hotel_name    976
# dtype: int64

# %%
# storing the rows with a non-null value for city_rank in another dataframe

data_clean_df=data_df[data_df['city_rank'].notna()]

# %%
# storing the list of the 44 hotels with no useable data 

data_missing_hotels_id = set(data_df['hotel_id'])-set(data_clean_df['hotel_id'])
data_missing_hotels_name = set(data_df['hotel_name'])-set(data_clean_df['hotel_name'])

# %%
data_missing_hotels_id
# Out:
# {'114341',
#  '176681',
#  '176691',
#  '176701',
#  '176711',
#  '236571',
#  '268841',
#  '268851',
#  '268861',
#  '268871',
#  '268891',
#  '268911',
#  '268941',
#  '319381',
#  '322581',
#  '324671',
#  '49621',
#  '49751',
#  '49761',
#  '49771',
#  '49781',
#  '49791'}

# %%
data_missing_hotels_name
# Out:
# {'Airline Moulinsart',
#  'Alter Krug',
#  'Cafe am neuen See',
#  'Germania Airlines',
#  'Grands Augustins/2154',
#  'INDUSTRY STANDARD',
#  'Loretta am Wannsee',
#  'Luise',
#  'Orderbird',
#  'Prater Garten Berlin',
#  'Restaurant Horváth',
#  'Schleusenkrug',
#  'Small Planet Airlines',
#  'Sweet Inn BERTHE I',
#  'Sweet Inn BOETIE IV',
#  'Sweet Inn BRANCION',
#  'Sweet Inn RAVIGNAN I',
#  'Sweet Inn RAVIGNAN II',
#  'Sweet Inn RIVOLI II',
#  'Sweet Inn ROQUETTE III',
#  'TXOKOA',
#  'Wirtshaus Max und Moritz'}

# %%
# examining the rows of an example of these hotels. 

data_missing_example_df = data_df[data_df['hotel_id'] == '114341']

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
     print(data_missing_example_df.head())
# Out:
#        hotel_id hotel_name                       street zip_code    city  \
# 461409   114341  Orderbird  Ritterstraße 12-14, Aufg. 4    10969  Berlin
# 461410   114341  Orderbird  Ritterstraße 12-14, Aufg. 4    10969  Berlin
# 461411   114341  Orderbird  Ritterstraße 12-14, Aufg. 4    10969  Berlin
# 461412   114341  Orderbird  Ritterstraße 12-14, Aufg. 4    10969  Berlin
# 461413   114341  Orderbird  Ritterstraße 12-14, Aufg. 4    10969  Berlin
#
#        country  crawled_at  review_count_state  average_rating_state  \
# 461409      DE  2016-06-01                 217                  80.0
# 461410      DE  2016-06-02                 217                  80.0
# 461411      DE  2016-06-03                 217                  80.0
# 461412      DE  2016-06-04                 217                  80.0
# 461413      DE  2016-06-05                 217                  80.0
#
#         sleep_rating_state  location_rating_state  room_rating_state  \
# 461409                 NaN                    NaN                NaN
# 461410                 NaN                    NaN                NaN
# 461411                 NaN                    NaN                NaN
# 461412                 NaN                    NaN                NaN
# 461413                 NaN                    NaN                NaN
#
#         service_rating_state  value_rating_state  clean_rating_state  \
# 461409                   NaN                 NaN                 NaN
# 461410                   NaN                 NaN                 NaN
# 461411                   NaN                 NaN                 NaN
# 461412                   NaN                 NaN                 NaN
# 461413                   NaN                 NaN                 NaN
#
#         city_rank  cities  hotel_rank  response_rate_negative_count_todate  \
# 461409        NaN     NaN         NaN                                  NaN
# 461410        NaN     NaN         NaN                                  NaN
# 461411        NaN     NaN         NaN                                  NaN
# 461412        NaN     NaN         NaN                                  NaN
# 461413        NaN     NaN         NaN                                  NaN
#
#         response_rate_neutral_count_todate  \
# 461409                                 NaN
# 461410                                 NaN
# 461411                                 NaN
# 461412                                 NaN
# 461413                                 NaN
#
#         response_rate_positive_count_todate  response_rate_count_todate  \
# 461409                                  NaN                         NaN
# 461410                                  NaN                         NaN
# 461411                                  NaN                         NaN
# 461412                                  NaN                         NaN
# 461413                                  NaN                         NaN
#
#         response_rate_negative_todate  response_rate_neutral_todate  \
# 461409                            NaN                           NaN
# 461410                            NaN                           NaN
# 461411                            NaN                           NaN
# 461412                            NaN                           NaN
# 461413                            NaN                           NaN
#
#         response_rate_positive_todate  response_rate_todate  \
# 461409                            NaN                   NaN
# 461410                            NaN                   NaN
# 461411                            NaN                   NaN
# 461412                            NaN                   NaN
# 461413                            NaN                   NaN
#
#         average_rating_positive_count_todate  \
# 461409                                   NaN
# 461410                                   NaN
# 461411                                   NaN
# 461412                                   NaN
# 461413                                   NaN
#
#         average_rating_neutral_count_todate  \
# 461409                                  NaN
# 461410                                  NaN
# 461411                                  NaN
# 461412                                  NaN
# 461413                                  NaN
#
#         average_rating_negative_count_todate  average_rating_count_todate  \
# 461409                                   NaN                          NaN
# 461410                                   NaN                          NaN
# 461411                                   NaN                          NaN
# 461412                                   NaN                          NaN
# 461413                                   NaN                          NaN
#
#         average_rating_normalized_todate  sleep_rating_positive_count_todate  \
# 461409                               NaN                                 NaN
# 461410                               NaN                                 NaN
# 461411                               NaN                                 NaN
# 461412                               NaN                                 NaN
# 461413                               NaN                                 NaN
#
#         sleep_rating_neutral_count_todate  sleep_rating_negative_count_todate  \
# 461409                                NaN                                 NaN
# 461410                                NaN                                 NaN
# 461411                                NaN                                 NaN
# 461412                                NaN                                 NaN
# 461413                                NaN                                 NaN
#
#         sleep_rating_count_todate  sleep_rating_normalized_todate  \
# 461409                        NaN                             NaN
# 461410                        NaN                             NaN
# 461411                        NaN                             NaN
# 461412                        NaN                             NaN
# 461413                        NaN                             NaN
#
#         location_rating_positive_count_todate  \
# 461409                                    NaN
# 461410                                    NaN
# 461411                                    NaN
# 461412                                    NaN
# 461413                                    NaN
#
#         location_rating_neutral_count_todate  \
# 461409                                   NaN
# 461410                                   NaN
# 461411                                   NaN
# 461412                                   NaN
# 461413                                   NaN
#
#         location_rating_negative_count_todate  location_rating_count_todate  \
# 461409                                    NaN                           NaN
# 461410                                    NaN                           NaN
# 461411                                    NaN                           NaN
# 461412                                    NaN                           NaN
# 461413                                    NaN                           NaN
#
#         location_rating_normalized_todate  room_rating_positive_count_todate  \
# 461409                                NaN                                NaN
# 461410                                NaN                                NaN
# 461411                                NaN                                NaN
# 461412                                NaN                                NaN
# 461413                                NaN                                NaN
#
#         room_rating_neutral_count_todate  room_rating_negative_count_todate  \
# 461409                               NaN                                NaN
# 461410                               NaN                                NaN
# 461411                               NaN                                NaN
# 461412                               NaN                                NaN
# 461413                               NaN                                NaN
#
#         room_rating_count_todate  room_rating_normalized_todate  \
# 461409                       NaN                            NaN
# 461410                       NaN                            NaN
# 461411                       NaN                            NaN
# 461412                       NaN                            NaN
# 461413                       NaN                            NaN
#
#         service_rating_positive_count_todate  \
# 461409                                   NaN
# 461410                                   NaN
# 461411                                   NaN
# 461412                                   NaN
# 461413                                   NaN
#
#         service_rating_neutral_count_todate  \
# 461409                                  NaN
# 461410                                  NaN
# 461411                                  NaN
# 461412                                  NaN
# 461413                                  NaN
#
#         service_rating_negative_count_todate  service_rating_count_todate  \
# 461409                                   NaN                          NaN
# 461410                                   NaN                          NaN
# 461411                                   NaN                          NaN
# 461412                                   NaN                          NaN
# 461413                                   NaN                          NaN
#
#         service_rating_normalized_todate  value_rating_positive_count_todate  \
# 461409                               NaN                                 NaN
# 461410                               NaN                                 NaN
# 461411                               NaN                                 NaN
# 461412                               NaN                                 NaN
# 461413                               NaN                                 NaN
#
#         value_rating_neutral_count_todate  value_rating_negative_count_todate  \
# 461409                                NaN                                 NaN
# 461410                                NaN                                 NaN
# 461411                                NaN                                 NaN
# 461412                                NaN                                 NaN
# 461413                                NaN                                 NaN
#
#         value_rating_count_todate  value_rating_normalized_todate  \
# 461409                        NaN                             NaN
# 461410                        NaN                             NaN
# 461411                        NaN                             NaN
# 461412                        NaN                             NaN
# 461413                        NaN                             NaN
#
#         clean_rating_positive_count_todate  clean_rating_neutral_count_todate  \
# 461409                                 NaN                                NaN
# 461410                                 NaN                                NaN
# 461411                                 NaN                                NaN
# 461412                                 NaN                                NaN
# 461413                                 NaN                                NaN
#
#         clean_rating_negative_count_todate  clean_rating_count_todate  \
# 461409                                 NaN                        NaN
# 461410                                 NaN                        NaN
# 461411                                 NaN                        NaN
# 461412                                 NaN                        NaN
# 461413                                 NaN                        NaN
#
#         clean_rating_normalized_todate
# 461409                             NaN
# 461410                             NaN
# 461411                             NaN
# 461412                             NaN
# 461413                             NaN

# %% [markdown]
# ### Segmenting the clean data into Berlin and Paris

# %%
print(data_clean_df['city'].value_counts(),'\n')
print(data_clean_df['country'].value_counts(),'\n')
# Out:
# Berlin                                       367427
# Paris                                        307882
# Paris 17                                       5731
# Paris 06                                       5120
# Paris 12                                       4698
# Berlin - Charlottenburg                        4616
# Paris 14                                       4611
# Paris 16                                       3628
# Paris 01                                       2740
# Paris 07                                       2544
# Paris 15                                       2111
# Paris 09                                       1823
# Paris 10                                       1562
# Paris 03                                       1488
# PARIS                                          1407
# Berlin - Spandau                                933
# Berlin-Schönefeld                               932
# Paris - Tour Eiffel                             928
# Berlin-Schmöckwitz                              928
# Paris - 6. Arr. -> St Germain des Prés          924
# Paris - Opera, St Lazare, Grands magasins       924
# Berlin - Adlershof                              923
# Berlin - Treptow                                921
# Paris - 6. Arrond.                              920
# Paris - Porte Maillot                           920
# Paris - Opéra Lafayette                         902
# Paris - Opéra                                   899
# Paris - Opera Lafayette                         897
# Berlin - Wilmersdorf                            777
# Berlin - Tiergarten                             695
# Berlin - Zehlendorf                             614
# Paris - 1. Arr. -> Louvre-Place Vendome         538
# Berlingerode                                    525
# Paris 05                                        484
# Berlin - Schönefeld                             456
# Paris 08                                        435
# Berlín                                          341
# Paris - 17. Arrond.                             186
# Paris - 10. Arr. -> Gare de l´Est / Nord        175
# Paris 04                                        172
# Paris 11                                        163
# Paris - 1. Arr. -> Louvre-Palais Royal           52
# Paris - 17. Arr. -> Palais des Congrès           14
# Name: city, dtype: int64
#
# DE    380112
# FR    354854
# Name: country, dtype: int64

# %%
# converting city name to all lower case

data_clean_df['city']=data_clean_df['city'].str.lower()
print(data_clean_df['city'].value_counts(),'\n')
# Out:
# C:\Users\Dina\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# berlin                                       367427
# paris                                        309289
# paris 17                                       5731
# paris 06                                       5120
# paris 12                                       4698
# berlin - charlottenburg                        4616
# paris 14                                       4611
# paris 16                                       3628
# paris 01                                       2740
# paris 07                                       2544
# paris 15                                       2111
# paris 09                                       1823
# paris 10                                       1562
# paris 03                                       1488
# berlin - spandau                                933
# berlin-schönefeld                               932
# paris - tour eiffel                             928
# berlin-schmöckwitz                              928
# paris - opera, st lazare, grands magasins       924
# paris - 6. arr. -> st germain des prés          924
# berlin - adlershof                              923
# berlin - treptow                                921
# paris - porte maillot                           920
# paris - 6. arrond.                              920
# paris - opéra lafayette                         902
# paris - opéra                                   899
# paris - opera lafayette                         897
# berlin - wilmersdorf                            777
# berlin - tiergarten                             695
# berlin - zehlendorf                             614
# paris - 1. arr. -> louvre-place vendome         538
# berlingerode                                    525
# paris 05                                        484
# berlin - schönefeld                             456
# paris 08                                        435
# berlín                                          341
# paris - 17. arrond.                             186
# paris - 10. arr. -> gare de l´est / nord        175
# paris 04                                        172
# paris 11                                        163
# paris - 1. arr. -> louvre-palais royal           52
# paris - 17. arr. -> palais des congrès           14
# Name: city, dtype: int64

# %%
data_clean_df[(data_clean_df['country']=='DE')].shape
# Out:
# (380112, 61)

# %%
sum(data_clean_df['city'].str.contains('berlin'))
# Out:
# 379747

# %%
data_clean_df[['city', 'country']].isnull().sum()
# Out:
# city       0
# country    0
# dtype: int64

# %%
# storing Berlin Germany data in a separate dataframe. Berlin is entered in a non-consistent way

berlin_df=data_clean_df[(data_clean_df['country']=='DE') & (data_clean_df['city'].str.contains('berlin')|
                                                            data_clean_df['city'].str.contains('berlín'))]
berlin_df.shape
# Out:
# (380088, 61)

# %%
# storing Paris France data in a separate dataframe

paris_df=data_clean_df[(data_clean_df['country']=='FR') & (data_clean_df['city'].str.contains('paris'))]
paris_df.shape
# Out:
# (354854, 61)

# %%
data_clean_df[(data_clean_df['country']=='DE') & (data_clean_df['city'].str.contains('paris'))].shape
# Out:
# (24, 61)

# %% [markdown]
# ### Verifying features' definitions

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
     print(berlin_df.head())
# Out:
#   hotel_id              hotel_name            street zip_code    city country  \
# 0       50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  berlin      DE
# 1       50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  berlin      DE
# 2       50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  berlin      DE
# 3       50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  berlin      DE
# 4       50  Bleibtreu Hotel Berlin  Bleibtreustr. 31    10707  berlin      DE
#
#    crawled_at  review_count_state  average_rating_state  sleep_rating_state  \
# 0  2015-08-19                 270                  80.0                80.0
# 1  2015-08-20                 270                  80.0                80.0
# 2  2015-08-21                 270                  80.0                80.0
# 3  2015-08-22                 270                  80.0                80.0
# 4  2015-08-23                 270                  80.0                80.0
#
#    location_rating_state  room_rating_state  service_rating_state  \
# 0                   90.0               80.0                  90.0
# 1                   90.0               80.0                  90.0
# 2                   90.0               80.0                  90.0
# 3                   90.0               80.0                  90.0
# 4                   90.0               80.0                  90.0
#
#    value_rating_state  clean_rating_state  city_rank  cities  hotel_rank  \
# 0                80.0                90.0      144.0   668.0         NaN
# 1                80.0                90.0      144.0   668.0         NaN
# 2                80.0                90.0      145.0   668.0         NaN
# 3                80.0                90.0      146.0   668.0         NaN
# 4                80.0                90.0      146.0   668.0         NaN
#
#    response_rate_negative_count_todate  response_rate_neutral_count_todate  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#    response_rate_positive_count_todate  response_rate_count_todate  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    response_rate_negative_todate  response_rate_neutral_todate  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    response_rate_positive_todate  response_rate_todate  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
#
#    average_rating_positive_count_todate  average_rating_neutral_count_todate  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    average_rating_negative_count_todate  average_rating_count_todate  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    average_rating_normalized_todate  sleep_rating_positive_count_todate  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sleep_rating_neutral_count_todate  sleep_rating_negative_count_todate  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    sleep_rating_count_todate  sleep_rating_normalized_todate  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    location_rating_positive_count_todate  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    location_rating_neutral_count_todate  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    location_rating_negative_count_todate  location_rating_count_todate  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
#
#    location_rating_normalized_todate  room_rating_positive_count_todate  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    room_rating_neutral_count_todate  room_rating_negative_count_todate  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    room_rating_count_todate  room_rating_normalized_todate  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#    service_rating_positive_count_todate  service_rating_neutral_count_todate  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    service_rating_negative_count_todate  service_rating_count_todate  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    service_rating_normalized_todate  value_rating_positive_count_todate  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    value_rating_neutral_count_todate  value_rating_negative_count_todate  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    value_rating_count_todate  value_rating_normalized_todate  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    clean_rating_positive_count_todate  clean_rating_neutral_count_todate  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
#
#    clean_rating_negative_count_todate  clean_rating_count_todate  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
#
#    clean_rating_normalized_todate
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# ** Important Equations **
#
# - response_rate_count_todate = response_rate_negative_count_todate + response_rate_neutral_count_todate+response_rate_positive_count_todate
#
# - response_rate_todate = (response_rate_negative_todate + response_rate_neutral_todate + response_rate_positive_todate)/3 ?
#
# -  average_rating_count_todate = average_rating_negative_count_todate + average_rating_neutral_count_todate + average_rating_positive_count_todate
#
# - previous equation also applies to clean, service, location, value, room, sleep
#
# - All ratings values (not counts) are on a percentile scale
#
# - Cities appears to be on area NOT city
#
# - On dates where there are no new reviews available at all, NaNs are placed for all to_date features

# %% [markdown]
# ## Weekly stats for Paris

# %% [markdown]
# **step 1**: building a dataframe that contains all the state columns sampled by week (taking maximum as the weekly state) per hotel id

# %%
paris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354854 entries, 92469 to 776336
# Data columns (total 61 columns):
# hotel_id                                 354854 non-null object
# hotel_name                               354854 non-null object
# street                                   354854 non-null object
# zip_code                                 354854 non-null object
# city                                     354854 non-null object
# country                                  354854 non-null object
# crawled_at                               354854 non-null object
# review_count_state                       354854 non-null int64
# average_rating_state                     354854 non-null float64
# sleep_rating_state                       66565 non-null float64
# location_rating_state                    66582 non-null float64
# room_rating_state                        66565 non-null float64
# service_rating_state                     66582 non-null float64
# value_rating_state                       66565 non-null float64
# clean_rating_state                       66582 non-null float64
# city_rank                                354854 non-null float64
# cities                                   354854 non-null float64
# hotel_rank                               0 non-null float64
# response_rate_negative_count_todate      72308 non-null float64
# response_rate_neutral_count_todate       72308 non-null float64
# response_rate_positive_count_todate      72308 non-null float64
# response_rate_count_todate               72308 non-null float64
# response_rate_negative_todate            72308 non-null float64
# response_rate_neutral_todate             72308 non-null float64
# response_rate_positive_todate            72308 non-null float64
# response_rate_todate                     72308 non-null float64
# average_rating_positive_count_todate     72308 non-null float64
# average_rating_neutral_count_todate      72308 non-null float64
# average_rating_negative_count_todate     72308 non-null float64
# average_rating_count_todate              72308 non-null float64
# average_rating_normalized_todate         72308 non-null float64
# sleep_rating_positive_count_todate       72308 non-null float64
# sleep_rating_neutral_count_todate        72308 non-null float64
# sleep_rating_negative_count_todate       72308 non-null float64
# sleep_rating_count_todate                72308 non-null float64
# sleep_rating_normalized_todate           72308 non-null float64
# location_rating_positive_count_todate    72308 non-null float64
# location_rating_neutral_count_todate     72308 non-null float64
# location_rating_negative_count_todate    72308 non-null float64
# location_rating_count_todate             72308 non-null float64
# location_rating_normalized_todate        72308 non-null float64
# room_rating_positive_count_todate        72308 non-null float64
# room_rating_neutral_count_todate         72308 non-null float64
# room_rating_negative_count_todate        72308 non-null float64
# room_rating_count_todate                 72308 non-null float64
# room_rating_normalized_todate            72308 non-null float64
# service_rating_positive_count_todate     72308 non-null float64
# service_rating_neutral_count_todate      72308 non-null float64
# service_rating_negative_count_todate     72308 non-null float64
# service_rating_count_todate              72308 non-null float64
# service_rating_normalized_todate         72308 non-null float64
# value_rating_positive_count_todate       72308 non-null float64
# value_rating_neutral_count_todate        72308 non-null float64
# value_rating_negative_count_todate       72308 non-null float64
# value_rating_count_todate                72308 non-null float64
# value_rating_normalized_todate           72308 non-null float64
# clean_rating_positive_count_todate       72308 non-null float64
# clean_rating_neutral_count_todate        72308 non-null float64
# clean_rating_negative_count_todate       72308 non-null float64
# clean_rating_count_todate                72308 non-null float64
# clean_rating_normalized_todate           72308 non-null float64
# dtypes: float64(53), int64(1), object(7)
# memory usage: 167.9+ MB

# %%
# list of all state columns in paris dataframe

state_cols = [col for col in paris_df if 'state' in col]
print(state_cols)
# Out:
# ['review_count_state', 'average_rating_state', 'sleep_rating_state', 'location_rating_state', 'room_rating_state', 'service_rating_state', 'value_rating_state', 'clean_rating_state']

# %%
# parsing crawled_at column as datetime

paris_df['crawled_at']=pd.to_datetime(paris_df['crawled_at'])
# Out:
# C:\Users\Dina\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# for state columns, we should take the maximum value of the week for every hotel id

paris_byhotel_byweek_state = paris_df.groupby(['hotel_id', pd.Grouper(key='crawled_at', freq='W')])[state_cols].max(skipna=True)

# %%
paris_byhotel_byweek_state.head()
# Out:
#                      review_count_state  average_rating_state  \
# hotel_id crawled_at
# 100421   2015-08-23                 346                  80.0
#          2015-08-30                 348                  80.0
#          2015-09-06                 349                  80.0
#          2015-09-13                 352                  80.0
#          2015-09-20                 355                  80.0
#
#                      sleep_rating_state  location_rating_state  \
# hotel_id crawled_at
# 100421   2015-08-23                90.0                   90.0
#          2015-08-30                90.0                   90.0
#          2015-09-06                90.0                   90.0
#          2015-09-13                90.0                   90.0
#          2015-09-20                90.0                   90.0
#
#                      room_rating_state  service_rating_state  \
# hotel_id crawled_at
# 100421   2015-08-23               80.0                  80.0
#          2015-08-30               80.0                  80.0
#          2015-09-06               80.0                  80.0
#          2015-09-13               80.0                  80.0
#          2015-09-20               80.0                  80.0
#
#                      value_rating_state  clean_rating_state
# hotel_id crawled_at
# 100421   2015-08-23                80.0                90.0
#          2015-08-30                80.0                90.0
#          2015-09-06                80.0                90.0
#          2015-09-13                80.0                90.0
#          2015-09-20                80.0                90.0

# %%
paris_byhotel_byweek_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 53224 entries, (100421, 2015-08-23 00:00:00) to (92741, 2018-04-29 00:00:00)
# Data columns (total 8 columns):
# review_count_state       53224 non-null int64
# average_rating_state     53224 non-null float64
# sleep_rating_state       10610 non-null float64
# location_rating_state    10614 non-null float64
# room_rating_state        10610 non-null float64
# service_rating_state     10614 non-null float64
# value_rating_state       10610 non-null float64
# clean_rating_state       10614 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 3.5+ MB

# %%
# There are weeks were all the rows for the week for sleep/location... state is NaN so the max is also NaN

test=pd.DataFrame(data=np.array([np.nan, 9, np.nan, np.nan]))
print(test.max(skipna=True))
test_allnan=pd.DataFrame(data=np.array([np.nan, np.nan, np.nan, np.nan]))
print(test_allnan.max(skipna=True))
# Out:
# 0    9.0
# dtype: float64
# 0   NaN
# dtype: float64

# %% [markdown]
# **step 2**: building a dataframe that contains all the count_todate columns sampled by week (taking sum of the week) per hotel id

# %%
# list of all count+todate columns in paris dataframe

count_todate_cols = [col for col in paris_df if 'count_todate' in col]
print(count_todate_cols)
# Out:
# ['response_rate_negative_count_todate', 'response_rate_neutral_count_todate', 'response_rate_positive_count_todate', 'response_rate_count_todate', 'average_rating_positive_count_todate', 'average_rating_neutral_count_todate', 'average_rating_negative_count_todate', 'average_rating_count_todate', 'sleep_rating_positive_count_todate', 'sleep_rating_neutral_count_todate', 'sleep_rating_negative_count_todate', 'sleep_rating_count_todate', 'location_rating_positive_count_todate', 'location_rating_neutral_count_todate', 'location_rating_negative_count_todate', 'location_rating_count_todate', 'room_rating_positive_count_todate', 'room_rating_neutral_count_todate', 'room_rating_negative_count_todate', 'room_rating_count_todate', 'service_rating_positive_count_todate', 'service_rating_neutral_count_todate', 'service_rating_negative_count_todate', 'service_rating_count_todate', 'value_rating_positive_count_todate', 'value_rating_neutral_count_todate', 'value_rating_negative_count_todate', 'value_rating_count_todate', 'clean_rating_positive_count_todate', 'clean_rating_neutral_count_todate', 'clean_rating_negative_count_todate', 'clean_rating_count_todate']

# %%
# for count_todate columns, we should take the sum value of the week for every hotel id

paris_byhotel_byweek_count_todate = paris_df.groupby(['hotel_id', pd.Grouper(key='crawled_at', freq='W')])[count_todate_cols].sum(skipna=True)

# %%
paris_byhotel_byweek_count_todate.head()
# Out:
#                      response_rate_negative_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                  0.0
#          2015-08-30                                  0.0
#          2015-09-06                                  0.0
#          2015-09-13                                  0.0
#          2015-09-20                                  0.0
#
#                      response_rate_neutral_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                 0.0
#          2015-08-30                                 0.0
#          2015-09-06                                 0.0
#          2015-09-13                                 1.0
#          2015-09-20                                 1.0
#
#                      response_rate_positive_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                  0.0
#          2015-08-30                                  2.0
#          2015-09-06                                  1.0
#          2015-09-13                                  4.0
#          2015-09-20                                  1.0
#
#                      response_rate_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                         0.0
#          2015-08-30                         2.0
#          2015-09-06                         1.0
#          2015-09-13                         5.0
#          2015-09-20                         2.0
#
#                      average_rating_positive_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                   0.0
#          2015-08-30                                   2.0
#          2015-09-06                                   1.0
#          2015-09-13                                   4.0
#          2015-09-20                                   1.0
#
#                      average_rating_neutral_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                  0.0
#          2015-08-30                                  0.0
#          2015-09-06                                  0.0
#          2015-09-13                                  1.0
#          2015-09-20                                  1.0
#
#                      average_rating_negative_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                   0.0
#          2015-08-30                                   0.0
#          2015-09-06                                   0.0
#          2015-09-13                                   0.0
#          2015-09-20                                   0.0
#
#                      average_rating_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                          0.0
#          2015-08-30                          2.0
#          2015-09-06                          1.0
#          2015-09-13                          5.0
#          2015-09-20                          2.0
#
#                      sleep_rating_positive_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                 0.0
#          2015-08-30                                 1.0
#          2015-09-06                                 0.0
#          2015-09-13                                 3.0
#          2015-09-20                                 0.0
#
#                      sleep_rating_neutral_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                0.0
#          2015-08-30                                0.0
#          2015-09-06                                0.0
#          2015-09-13                                0.0
#          2015-09-20                                0.0
#
#                                ...              \
# hotel_id crawled_at            ...
# 100421   2015-08-23            ...
#          2015-08-30            ...
#          2015-09-06            ...
#          2015-09-13            ...
#          2015-09-20            ...
#
#                      service_rating_negative_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                   0.0
#          2015-08-30                                   0.0
#          2015-09-06                                   0.0
#          2015-09-13                                   0.0
#          2015-09-20                                   0.0
#
#                      service_rating_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                          0.0
#          2015-08-30                          1.0
#          2015-09-06                          1.0
#          2015-09-13                          3.0
#          2015-09-20                          0.0
#
#                      value_rating_positive_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                 0.0
#          2015-08-30                                 0.0
#          2015-09-06                                 1.0
#          2015-09-13                                 0.0
#          2015-09-20                                 0.0
#
#                      value_rating_neutral_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                0.0
#          2015-08-30                                0.0
#          2015-09-06                                0.0
#          2015-09-13                                0.0
#          2015-09-20                                0.0
#
#                      value_rating_negative_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                 0.0
#          2015-08-30                                 0.0
#          2015-09-06                                 0.0
#          2015-09-13                                 0.0
#          2015-09-20                                 0.0
#
#                      value_rating_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                        0.0
#          2015-08-30                        0.0
#          2015-09-06                        1.0
#          2015-09-13                        0.0
#          2015-09-20                        0.0
#
#                      clean_rating_positive_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                 0.0
#          2015-08-30                                 0.0
#          2015-09-06                                 1.0
#          2015-09-13                                 1.0
#          2015-09-20                                 0.0
#
#                      clean_rating_neutral_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                0.0
#          2015-08-30                                0.0
#          2015-09-06                                0.0
#          2015-09-13                                0.0
#          2015-09-20                                0.0
#
#                      clean_rating_negative_count_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                 0.0
#          2015-08-30                                 0.0
#          2015-09-06                                 0.0
#          2015-09-13                                 0.0
#          2015-09-20                                 0.0
#
#                      clean_rating_count_todate
# hotel_id crawled_at
# 100421   2015-08-23                        0.0
#          2015-08-30                        0.0
#          2015-09-06                        1.0
#          2015-09-13                        1.0
#          2015-09-20                        0.0
#
# [5 rows x 32 columns]

# %%
paris_byhotel_byweek_count_todate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 53224 entries, (100421, 2015-08-23 00:00:00) to (92741, 2018-04-29 00:00:00)
# Data columns (total 32 columns):
# response_rate_negative_count_todate      53224 non-null float64
# response_rate_neutral_count_todate       53224 non-null float64
# response_rate_positive_count_todate      53224 non-null float64
# response_rate_count_todate               53224 non-null float64
# average_rating_positive_count_todate     53224 non-null float64
# average_rating_neutral_count_todate      53224 non-null float64
# average_rating_negative_count_todate     53224 non-null float64
# average_rating_count_todate              53224 non-null float64
# sleep_rating_positive_count_todate       53224 non-null float64
# sleep_rating_neutral_count_todate        53224 non-null float64
# sleep_rating_negative_count_todate       53224 non-null float64
# sleep_rating_count_todate                53224 non-null float64
# location_rating_positive_count_todate    53224 non-null float64
# location_rating_neutral_count_todate     53224 non-null float64
# location_rating_negative_count_todate    53224 non-null float64
# location_rating_count_todate             53224 non-null float64
# room_rating_positive_count_todate        53224 non-null float64
# room_rating_neutral_count_todate         53224 non-null float64
# room_rating_negative_count_todate        53224 non-null float64
# room_rating_count_todate                 53224 non-null float64
# service_rating_positive_count_todate     53224 non-null float64
# service_rating_neutral_count_todate      53224 non-null float64
# service_rating_negative_count_todate     53224 non-null float64
# service_rating_count_todate              53224 non-null float64
# value_rating_positive_count_todate       53224 non-null float64
# value_rating_neutral_count_todate        53224 non-null float64
# value_rating_negative_count_todate       53224 non-null float64
# value_rating_count_todate                53224 non-null float64
# clean_rating_positive_count_todate       53224 non-null float64
# clean_rating_neutral_count_todate        53224 non-null float64
# clean_rating_negative_count_todate       53224 non-null float64
# clean_rating_count_todate                53224 non-null float64
# dtypes: float64(32)
# memory usage: 13.2+ MB

# %%
# There are weeks were all the rows for the week for sleep/location... state is NaN but the sum will be 0 in that case
# which is momentarily not a problem

test=pd.DataFrame(data=np.array([np.nan, 9, np.nan, np.nan]))
print(test.sum(skipna=True))
test_allnan=pd.DataFrame(data=np.array([np.nan, np.nan, np.nan, np.nan]))
print(test_allnan.sum(skipna=True))
# Out:
# 0    9.0
# dtype: float64
# 0    0.0
# dtype: float64

# %% [markdown]
# **step 3**: building a dataframe that contains all the normalized_todate columns sampled by week (taking average of the week) per hotel id

# %%
# list of all normalized+todate columns in paris dataframe

normalized_todate_cols = [col for col in paris_df if 'normalized_todate' in col]
print(normalized_todate_cols)
# Out:
# ['average_rating_normalized_todate', 'sleep_rating_normalized_todate', 'location_rating_normalized_todate', 'room_rating_normalized_todate', 'service_rating_normalized_todate', 'value_rating_normalized_todate', 'clean_rating_normalized_todate']

# %%
# for count_todate columns, we should take the mean value of the week for every hotel id

paris_byhotel_byweek_normalized_todate = paris_df.groupby(['hotel_id', pd.Grouper(key='crawled_at', freq='W')])[normalized_todate_cols].mean()

# %%
paris_byhotel_byweek_normalized_todate.head()
# Out:
#                      average_rating_normalized_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                               NaN
#          2015-08-30                              90.0
#          2015-09-06                              80.0
#          2015-09-13                              80.0
#          2015-09-20                              70.0
#
#                      sleep_rating_normalized_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                             NaN
#          2015-08-30                            40.0
#          2015-09-06                             0.0
#          2015-09-13                            65.0
#          2015-09-20                             0.0
#
#                      location_rating_normalized_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                                NaN
#          2015-08-30                                0.0
#          2015-09-06                                0.0
#          2015-09-13                               40.0
#          2015-09-20                                0.0
#
#                      room_rating_normalized_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                            NaN
#          2015-08-30                           30.0
#          2015-09-06                            0.0
#          2015-09-13                            0.0
#          2015-09-20                            0.0
#
#                      service_rating_normalized_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                               NaN
#          2015-08-30                              40.0
#          2015-09-06                              80.0
#          2015-09-13                              65.0
#          2015-09-20                               0.0
#
#                      value_rating_normalized_todate  \
# hotel_id crawled_at
# 100421   2015-08-23                             NaN
#          2015-08-30                             0.0
#          2015-09-06                            80.0
#          2015-09-13                             0.0
#          2015-09-20                             0.0
#
#                      clean_rating_normalized_todate
# hotel_id crawled_at
# 100421   2015-08-23                             NaN
#          2015-08-30                             0.0
#          2015-09-06                           100.0
#          2015-09-13                            20.0
#          2015-09-20                             0.0

# %%
paris_byhotel_byweek_normalized_todate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 53224 entries, (100421, 2015-08-23 00:00:00) to (92741, 2018-04-29 00:00:00)
# Data columns (total 7 columns):
# average_rating_normalized_todate     35221 non-null float64
# sleep_rating_normalized_todate       35221 non-null float64
# location_rating_normalized_todate    35221 non-null float64
# room_rating_normalized_todate        35221 non-null float64
# service_rating_normalized_todate     35221 non-null float64
# value_rating_normalized_todate       35221 non-null float64
# clean_rating_normalized_todate       35221 non-null float64
# dtypes: float64(7)
# memory usage: 3.1+ MB

# %%
# There are weeks were all the rows for the week are NaN and the mean will be NaN in that case
# Also, the number of non-null values is equal for all 7 columns because of their connection

test=pd.DataFrame(data=np.array([np.nan, 9, np.nan, np.nan]))
print(test.mean(skipna=True))
test_allnan=pd.DataFrame(data=np.array([np.nan, np.nan, np.nan, np.nan]))
print(test_allnan.mean(skipna=True))
# Out:
# 0    9.0
# dtype: float64
# 0   NaN
# dtype: float64

# %%
# checking data of the first hotel to check work so far

_=paris_df[paris_df['hotel_id']=='100421']
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
     print(_.head(12))
# Out:
#        hotel_id                             hotel_name  \
# 331713   100421  BEST WESTERN Hotel Villa Des Artistes
# 331714   100421  BEST WESTERN Hotel Villa Des Artistes
# 331715   100421  BEST WESTERN Hotel Villa Des Artistes
# 331716   100421  BEST WESTERN Hotel Villa Des Artistes
# 331717   100421  BEST WESTERN Hotel Villa Des Artistes
# 331718   100421  BEST WESTERN Hotel Villa Des Artistes
# 331719   100421  BEST WESTERN Hotel Villa Des Artistes
# 331720   100421  BEST WESTERN Hotel Villa Des Artistes
# 331721   100421  BEST WESTERN Hotel Villa Des Artistes
# 331722   100421  BEST WESTERN Hotel Villa Des Artistes
# 331723   100421  BEST WESTERN Hotel Villa Des Artistes
# 331724   100421  BEST WESTERN Hotel Villa Des Artistes
#
#                               street zip_code   city country crawled_at  \
# 331713  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-19
# 331714  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-20
# 331715  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-21
# 331716  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-22
# 331717  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-23
# 331718  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-24
# 331719  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-25
# 331720  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-26
# 331721  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-27
# 331722  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-28
# 331723  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-29
# 331724  9 Rue De La Grande Chaumiere    75006  paris      FR 2015-08-30
#
#         review_count_state  average_rating_state  sleep_rating_state  \
# 331713                 346                  80.0                90.0
# 331714                 346                  80.0                90.0
# 331715                 346                  80.0                90.0
# 331716                 346                  80.0                90.0
# 331717                 346                  80.0                90.0
# 331718                 346                  80.0                90.0
# 331719                 346                  80.0                90.0
# 331720                 346                  80.0                90.0
# 331721                 347                  80.0                90.0
# 331722                 348                  80.0                90.0
# 331723                 348                  80.0                90.0
# 331724                 348                  80.0                90.0
#
#         location_rating_state  room_rating_state  service_rating_state  \
# 331713                   90.0               80.0                  80.0
# 331714                   90.0               80.0                  80.0
# 331715                   90.0               80.0                  80.0
# 331716                   90.0               80.0                  80.0
# 331717                   90.0               80.0                  80.0
# 331718                   90.0               80.0                  80.0
# 331719                   90.0               80.0                  80.0
# 331720                   90.0               80.0                  80.0
# 331721                   90.0               80.0                  80.0
# 331722                   90.0               80.0                  80.0
# 331723                   90.0               80.0                  80.0
# 331724                   90.0               80.0                  80.0
#
#         value_rating_state  clean_rating_state  city_rank  cities  hotel_rank  \
# 331713                80.0                90.0      350.0  1791.0         NaN
# 331714                80.0                90.0      350.0  1791.0         NaN
# 331715                80.0                90.0      352.0  1791.0         NaN
# 331716                80.0                90.0      353.0  1791.0         NaN
# 331717                80.0                90.0      353.0  1791.0         NaN
# 331718                80.0                90.0      354.0  1791.0         NaN
# 331719                80.0                90.0      354.0  1791.0         NaN
# 331720                80.0                90.0      354.0  1791.0         NaN
# 331721                80.0                90.0      353.0  1791.0         NaN
# 331722                80.0                90.0      348.0  1791.0         NaN
# 331723                80.0                90.0      350.0  1791.0         NaN
# 331724                80.0                90.0      352.0  1791.0         NaN
#
#         response_rate_negative_count_todate  \
# 331713                                  NaN
# 331714                                  NaN
# 331715                                  NaN
# 331716                                  NaN
# 331717                                  NaN
# 331718                                  NaN
# 331719                                  0.0
# 331720                                  NaN
# 331721                                  0.0
# 331722                                  NaN
# 331723                                  NaN
# 331724                                  NaN
#
#         response_rate_neutral_count_todate  \
# 331713                                 NaN
# 331714                                 NaN
# 331715                                 NaN
# 331716                                 NaN
# 331717                                 NaN
# 331718                                 NaN
# 331719                                 0.0
# 331720                                 NaN
# 331721                                 0.0
# 331722                                 NaN
# 331723                                 NaN
# 331724                                 NaN
#
#         response_rate_positive_count_todate  response_rate_count_todate  \
# 331713                                  NaN                         NaN
# 331714                                  NaN                         NaN
# 331715                                  NaN                         NaN
# 331716                                  NaN                         NaN
# 331717                                  NaN                         NaN
# 331718                                  NaN                         NaN
# 331719                                  1.0                         1.0
# 331720                                  NaN                         NaN
# 331721                                  1.0                         1.0
# 331722                                  NaN                         NaN
# 331723                                  NaN                         NaN
# 331724                                  NaN                         NaN
#
#         response_rate_negative_todate  response_rate_neutral_todate  \
# 331713                            NaN                           NaN
# 331714                            NaN                           NaN
# 331715                            NaN                           NaN
# 331716                            NaN                           NaN
# 331717                            NaN                           NaN
# 331718                            NaN                           NaN
# 331719                            0.0                           0.0
# 331720                            NaN                           NaN
# 331721                            0.0                           0.0
# 331722                            NaN                           NaN
# 331723                            NaN                           NaN
# 331724                            NaN                           NaN
#
#         response_rate_positive_todate  response_rate_todate  \
# 331713                            NaN                   NaN
# 331714                            NaN                   NaN
# 331715                            NaN                   NaN
# 331716                            NaN                   NaN
# 331717                            NaN                   NaN
# 331718                            NaN                   NaN
# 331719                            0.0                   0.0
# 331720                            NaN                   NaN
# 331721                            0.0                   0.0
# 331722                            NaN                   NaN
# 331723                            NaN                   NaN
# 331724                            NaN                   NaN
#
#         average_rating_positive_count_todate  \
# 331713                                   NaN
# 331714                                   NaN
# 331715                                   NaN
# 331716                                   NaN
# 331717                                   NaN
# 331718                                   NaN
# 331719                                   1.0
# 331720                                   NaN
# 331721                                   1.0
# 331722                                   NaN
# 331723                                   NaN
# 331724                                   NaN
#
#         average_rating_neutral_count_todate  \
# 331713                                  NaN
# 331714                                  NaN
# 331715                                  NaN
# 331716                                  NaN
# 331717                                  NaN
# 331718                                  NaN
# 331719                                  0.0
# 331720                                  NaN
# 331721                                  0.0
# 331722                                  NaN
# 331723                                  NaN
# 331724                                  NaN
#
#         average_rating_negative_count_todate  average_rating_count_todate  \
# 331713                                   NaN                          NaN
# 331714                                   NaN                          NaN
# 331715                                   NaN                          NaN
# 331716                                   NaN                          NaN
# 331717                                   NaN                          NaN
# 331718                                   NaN                          NaN
# 331719                                   0.0                          1.0
# 331720                                   NaN                          NaN
# 331721                                   0.0                          1.0
# 331722                                   NaN                          NaN
# 331723                                   NaN                          NaN
# 331724                                   NaN                          NaN
#
#         average_rating_normalized_todate  sleep_rating_positive_count_todate  \
# 331713                               NaN                                 NaN
# 331714                               NaN                                 NaN
# 331715                               NaN                                 NaN
# 331716                               NaN                                 NaN
# 331717                               NaN                                 NaN
# 331718                               NaN                                 NaN
# 331719                             100.0                                 0.0
# 331720                               NaN                                 NaN
# 331721                              80.0                                 1.0
# 331722                               NaN                                 NaN
# 331723                               NaN                                 NaN
# 331724                               NaN                                 NaN
#
#         sleep_rating_neutral_count_todate  sleep_rating_negative_count_todate  \
# 331713                                NaN                                 NaN
# 331714                                NaN                                 NaN
# 331715                                NaN                                 NaN
# 331716                                NaN                                 NaN
# 331717                                NaN                                 NaN
# 331718                                NaN                                 NaN
# 331719                                0.0                                 0.0
# 331720                                NaN                                 NaN
# 331721                                0.0                                 0.0
# 331722                                NaN                                 NaN
# 331723                                NaN                                 NaN
# 331724                                NaN                                 NaN
#
#         sleep_rating_count_todate  sleep_rating_normalized_todate  \
# 331713                        NaN                             NaN
# 331714                        NaN                             NaN
# 331715                        NaN                             NaN
# 331716                        NaN                             NaN
# 331717                        NaN                             NaN
# 331718                        NaN                             NaN
# 331719                        0.0                             0.0
# 331720                        NaN                             NaN
# 331721                        1.0                            80.0
# 331722                        NaN                             NaN
# 331723                        NaN                             NaN
# 331724                        NaN                             NaN
#
#         location_rating_positive_count_todate  \
# 331713                                    NaN
# 331714                                    NaN
# 331715                                    NaN
# 331716                                    NaN
# 331717                                    NaN
# 331718                                    NaN
# 331719                                    0.0
# 331720                                    NaN
# 331721                                    0.0
# 331722                                    NaN
# 331723                                    NaN
# 331724                                    NaN
#
#         location_rating_neutral_count_todate  \
# 331713                                   NaN
# 331714                                   NaN
# 331715                                   NaN
# 331716                                   NaN
# 331717                                   NaN
# 331718                                   NaN
# 331719                                   0.0
# 331720                                   NaN
# 331721                                   0.0
# 331722                                   NaN
# 331723                                   NaN
# 331724                                   NaN
#
#         location_rating_negative_count_todate  location_rating_count_todate  \
# 331713                                    NaN                           NaN
# 331714                                    NaN                           NaN
# 331715                                    NaN                           NaN
# 331716                                    NaN                           NaN
# 331717                                    NaN                           NaN
# 331718                                    NaN                           NaN
# 331719                                    0.0                           0.0
# 331720                                    NaN                           NaN
# 331721                                    0.0                           0.0
# 331722                                    NaN                           NaN
# 331723                                    NaN                           NaN
# 331724                                    NaN                           NaN
#
#         location_rating_normalized_todate  room_rating_positive_count_todate  \
# 331713                                NaN                                NaN
# 331714                                NaN                                NaN
# 331715                                NaN                                NaN
# 331716                                NaN                                NaN
# 331717                                NaN                                NaN
# 331718                                NaN                                NaN
# 331719                                0.0                                0.0
# 331720                                NaN                                NaN
# 331721                                0.0                                0.0
# 331722                                NaN                                NaN
# 331723                                NaN                                NaN
# 331724                                NaN                                NaN
#
#         room_rating_neutral_count_todate  room_rating_negative_count_todate  \
# 331713                               NaN                                NaN
# 331714                               NaN                                NaN
# 331715                               NaN                                NaN
# 331716                               NaN                                NaN
# 331717                               NaN                                NaN
# 331718                               NaN                                NaN
# 331719                               0.0                                0.0
# 331720                               NaN                                NaN
# 331721                               1.0                                0.0
# 331722                               NaN                                NaN
# 331723                               NaN                                NaN
# 331724                               NaN                                NaN
#
#         room_rating_count_todate  room_rating_normalized_todate  \
# 331713                       NaN                            NaN
# 331714                       NaN                            NaN
# 331715                       NaN                            NaN
# 331716                       NaN                            NaN
# 331717                       NaN                            NaN
# 331718                       NaN                            NaN
# 331719                       0.0                            0.0
# 331720                       NaN                            NaN
# 331721                       1.0                           60.0
# 331722                       NaN                            NaN
# 331723                       NaN                            NaN
# 331724                       NaN                            NaN
#
#         service_rating_positive_count_todate  \
# 331713                                   NaN
# 331714                                   NaN
# 331715                                   NaN
# 331716                                   NaN
# 331717                                   NaN
# 331718                                   NaN
# 331719                                   0.0
# 331720                                   NaN
# 331721                                   1.0
# 331722                                   NaN
# 331723                                   NaN
# 331724                                   NaN
#
#         service_rating_neutral_count_todate  \
# 331713                                  NaN
# 331714                                  NaN
# 331715                                  NaN
# 331716                                  NaN
# 331717                                  NaN
# 331718                                  NaN
# 331719                                  0.0
# 331720                                  NaN
# 331721                                  0.0
# 331722                                  NaN
# 331723                                  NaN
# 331724                                  NaN
#
#         service_rating_negative_count_todate  service_rating_count_todate  \
# 331713                                   NaN                          NaN
# 331714                                   NaN                          NaN
# 331715                                   NaN                          NaN
# 331716                                   NaN                          NaN
# 331717                                   NaN                          NaN
# 331718                                   NaN                          NaN
# 331719                                   0.0                          0.0
# 331720                                   NaN                          NaN
# 331721                                   0.0                          1.0
# 331722                                   NaN                          NaN
# 331723                                   NaN                          NaN
# 331724                                   NaN                          NaN
#
#         service_rating_normalized_todate  value_rating_positive_count_todate  \
# 331713                               NaN                                 NaN
# 331714                               NaN                                 NaN
# 331715                               NaN                                 NaN
# 331716                               NaN                                 NaN
# 331717                               NaN                                 NaN
# 331718                               NaN                                 NaN
# 331719                               0.0                                 0.0
# 331720                               NaN                                 NaN
# 331721                              80.0                                 0.0
# 331722                               NaN                                 NaN
# 331723                               NaN                                 NaN
# 331724                               NaN                                 NaN
#
#         value_rating_neutral_count_todate  value_rating_negative_count_todate  \
# 331713                                NaN                                 NaN
# 331714                                NaN                                 NaN
# 331715                                NaN                                 NaN
# 331716                                NaN                                 NaN
# 331717                                NaN                                 NaN
# 331718                                NaN                                 NaN
# 331719                                0.0                                 0.0
# 331720                                NaN                                 NaN
# 331721                                0.0                                 0.0
# 331722                                NaN                                 NaN
# 331723                                NaN                                 NaN
# 331724                                NaN                                 NaN
#
#         value_rating_count_todate  value_rating_normalized_todate  \
# 331713                        NaN                             NaN
# 331714                        NaN                             NaN
# 331715                        NaN                             NaN
# 331716                        NaN                             NaN
# 331717                        NaN                             NaN
# 331718                        NaN                             NaN
# 331719                        0.0                             0.0
# 331720                        NaN                             NaN
# 331721                        0.0                             0.0
# 331722                        NaN                             NaN
# 331723                        NaN                             NaN
# 331724                        NaN                             NaN
#
#         clean_rating_positive_count_todate  clean_rating_neutral_count_todate  \
# 331713                                 NaN                                NaN
# 331714                                 NaN                                NaN
# 331715                                 NaN                                NaN
# 331716                                 NaN                                NaN
# 331717                                 NaN                                NaN
# 331718                                 NaN                                NaN
# 331719                                 0.0                                0.0
# 331720                                 NaN                                NaN
# 331721                                 0.0                                0.0
# 331722                                 NaN                                NaN
# 331723                                 NaN                                NaN
# 331724                                 NaN                                NaN
#
#         clean_rating_negative_count_todate  clean_rating_count_todate  \
# 331713                                 NaN                        NaN
# 331714                                 NaN                        NaN
# 331715                                 NaN                        NaN
# 331716                                 NaN                        NaN
# 331717                                 NaN                        NaN
# 331718                                 NaN                        NaN
# 331719                                 0.0                        0.0
# 331720                                 NaN                        NaN
# 331721                                 0.0                        0.0
# 331722                                 NaN                        NaN
# 331723                                 NaN                        NaN
# 331724                                 NaN                        NaN
#
#         clean_rating_normalized_todate
# 331713                             NaN
# 331714                             NaN
# 331715                             NaN
# 331716                             NaN
# 331717                             NaN
# 331718                             NaN
# 331719                             0.0
# 331720                             NaN
# 331721                             0.0
# 331722                             NaN
# 331723                             NaN
# 331724                             NaN

# %%
# the sleep/room/... normaized_todate columns have a bug: zeros are placed on dates where there is a non-null value for 
#count_todate columns, but the zeros should NaNs because they do not reflect a value

#easy solution: replace zeros in normalized_to_date columns with NaN, assuming in a 5 stars system on trip-advisor customers 
# CAN NOT give zero starts
